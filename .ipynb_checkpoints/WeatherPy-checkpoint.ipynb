# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_df = pd.DataFrame(cities)
cities_df.rename(columns={0:"Cities"}, inplace = True)
cities_df
# Out:
#                      Cities
# 0                     ancud
# 1                    dalvik
# 2             srednekolymsk
# 3                vila velha
# 4                   changtu
# ..                      ...
# 623                    yaan
# 624                  jawhar
# 625  san francisco de coray
# 626                 wahiawa
# 627                  calvia
#
# [628 rows x 1 columns]

# %%
# cities_df["Cloudiness"] = ""
# cities_df["Country"] = ""
# cities_df["Date"] = ""
# cities_df["Humidity"]=""
# cities_df["Lat"]=""
# cities_df["Lng"]=""
# cities_df["Max Temperature (F)"]=""
# cities_df["Wind Speed (mph)"]=""
# cities_df.head(10)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
for index, row in cities_df.iterrows():

    cities_df.loc[cities_df.index, "Cities"]


# API Request below has been proven successful
    weather_url = "http://api.openweathermap.org/data/2.5/weather?q="+cities[index]+"&units=imperial&appid="+weather_api_key
    data_wea = requests.get(weather_url)
    response = data_wea.json()
#     print(response)
#     print(json.dumps(response, indent = 4))
    try:
        cities_df.loc[index,"Forecast"] = response["weather"][0]["main"]
        cities_df.loc[index, "Cloudiness (%)"] = response["clouds"]["all"]
        cities_df.loc[index,"Country"] = response["sys"]["country"]
        cities_df.loc[index,"Date"] = datetime.fromtimestamp(response["dt"])
        cities_df.loc[index,"Humidity"] = response["main"]["humidity"]
        cities_df.loc[index,"Lat"] = response["coord"]["lat"]
        cities_df.loc[index,"Lng"] = response["coord"]["lon"]
        cities_df.loc[index,"Max Temperature (F)"] = response["main"]["temp_max"]
        cities_df.loc[index,"Wind Speed (mph)"]=response["wind"]["speed"]

    except KeyError:
        print(f"Retrieving Results for Index {index}: {cities[index]}.")
    print(f"Retrieving Results for Index {index}: {cities[index]}.")
# Out:
# Retrieving Results for Index 0: ancud.
# Retrieving Results for Index 1: dalvik.
# Retrieving Results for Index 2: srednekolymsk.
# Retrieving Results for Index 3: vila velha.
# Retrieving Results for Index 4: changtu.
# Retrieving Results for Index 5: san buenaventura.
# Retrieving Results for Index 6: puerto ayora.
# Retrieving Results for Index 7: puerto cabello.
# Retrieving Results for Index 8: thompson.
# Retrieving Results for Index 9: maxixe.
# Retrieving Results for Index 10: kitchener.
# Retrieving Results for Index 11: kenai.
# Retrieving Results for Index 12: chuy.
# Retrieving Results for Index 13: kapaa.
# Retrieving Results for Index 14: kirakira.
# Retrieving Results for Index 15: butaritari.
# Retrieving Results for Index 16: port elizabeth.
# Retrieving Results for Index 17: santa fe.
# Retrieving Results for Index 18: fortuna.
# Retrieving Results for Index 19: vaini.
# Retrieving Results for Index 20: busselton.
# Retrieving Results for Index 21: tuktoyaktuk.
# Retrieving Results for Index 22: asyut.
# Retrieving Results for Index 23: kihei.
# Retrieving Results for Index 24: albany.
# Retrieving Results for Index 25: marcona.
# Retrieving Results for Index 25: marcona.
# Retrieving Results for Index 26: carnarvon.
# Retrieving Results for Index 27: tilichiki.
# Retrieving Results for Index 28: cabo san lucas.
# Retrieving Results for Index 29: atuona.
# Retrieving Results for Index 30: teguise.
# Retrieving Results for Index 31: north bend.
# Retrieving Results for Index 32: mar del plata.
# Retrieving Results for Index 33: vilyuysk.
# Retrieving Results for Index 34: honjo.
# Retrieving Results for Index 35: yellowknife.
# Retrieving Results for Index 36: taraz.
# Retrieving Results for Index 37: skrunda.
# Retrieving Results for Index 38: grand river south east.
# Retrieving Results for Index 38: grand river south east.
# Retrieving Results for Index 39: dunedin.
# Retrieving Results for Index 40: ransang.
# Retrieving Results for Index 41: punta arenas.
# Retrieving Results for Index 42: illoqqortoormiut.
# Retrieving Results for Index 42: illoqqortoormiut.
# Retrieving Results for Index 43: jamestown.
# Retrieving Results for Index 44: luderitz.
# Retrieving Results for Index 45: geraldton.
# Retrieving Results for Index 46: dikson.
# Retrieving Results for Index 47: qaanaaq.
# Retrieving Results for Index 48: stepantsevo.
# Retrieving Results for Index 49: luwuk.
# Retrieving Results for Index 50: kodiak.
# Retrieving Results for Index 51: kaitangata.
# Retrieving Results for Index 52: lebu.
# Retrieving Results for Index 53: sola.
# Retrieving Results for Index 54: taolanaro.
# Retrieving Results for Index 54: taolanaro.
# Retrieving Results for Index 55: ust-ilimsk.
# Retrieving Results for Index 56: te anau.
# Retrieving Results for Index 57: solnechnyy.
# Retrieving Results for Index 58: bikaner.
# Retrieving Results for Index 59: caravelas.
# Retrieving Results for Index 60: hilo.
# Retrieving Results for Index 61: boundiali.
# Retrieving Results for Index 62: bousse.
# Retrieving Results for Index 63: lompoc.
# Retrieving Results for Index 64: rikitea.
# Retrieving Results for Index 65: iquitos.
# Retrieving Results for Index 66: khatanga.
# Retrieving Results for Index 67: florianopolis.
# Retrieving Results for Index 68: andenes.
# Retrieving Results for Index 69: mount darwin.
# Retrieving Results for Index 70: hanmer springs.
# Retrieving Results for Index 71: bacolod.
# Retrieving Results for Index 72: mataura.
# Retrieving Results for Index 73: ribeira grande.
# Retrieving Results for Index 74: obo.
# Retrieving Results for Index 75: longyearbyen.
# Retrieving Results for Index 76: araguacu.
# Retrieving Results for Index 77: sivaki.
# Retrieving Results for Index 78: cape town.
# Retrieving Results for Index 79: inirida.
# Retrieving Results for Index 80: anar darreh.
# Retrieving Results for Index 80: anar darreh.
# Retrieving Results for Index 81: gizo.
# Retrieving Results for Index 82: ushuaia.
# Retrieving Results for Index 83: cherskiy.
# Retrieving Results for Index 84: grand gaube.
# Retrieving Results for Index 85: katsuura.
# Retrieving Results for Index 86: verkhnyaya inta.
# Retrieving Results for Index 87: anaconda.
# Retrieving Results for Index 88: arraial do cabo.
# Retrieving Results for Index 89: makakilo city.
# Retrieving Results for Index 90: saint george.
# Retrieving Results for Index 91: mitsamiouli.
# Retrieving Results for Index 92: new norfolk.
# Retrieving Results for Index 93: lagoa.
# Retrieving Results for Index 94: troitsko-pechorsk.
# Retrieving Results for Index 95: aykhal.
# Retrieving Results for Index 96: aripuana.
# Retrieving Results for Index 97: bluff.
# Retrieving Results for Index 98: tessalit.
# Retrieving Results for Index 99: san onofre.
# Retrieving Results for Index 100: tasiilaq.
# Retrieving Results for Index 101: hobart.
# Retrieving Results for Index 102: lasa.
# Retrieving Results for Index 103: hermanus.
# Retrieving Results for Index 104: puerto madryn.
# Retrieving Results for Index 105: hamilton.
# Retrieving Results for Index 106: victoria.
# Retrieving Results for Index 107: estelle.
# Retrieving Results for Index 108: torbay.
# Retrieving Results for Index 109: ponta do sol.
# Retrieving Results for Index 110: comodoro rivadavia.
# Retrieving Results for Index 111: derzhavinsk.
# Retrieving Results for Index 112: markapur.
# Retrieving Results for Index 113: mareeba.
# Retrieving Results for Index 114: esperance.
# Retrieving Results for Index 115: zarinsk.
# Retrieving Results for Index 116: saleaula.
# Retrieving Results for Index 116: saleaula.
# Retrieving Results for Index 117: codrington.
# Retrieving Results for Index 118: ronne.
# Retrieving Results for Index 119: thinadhoo.
# Retrieving Results for Index 120: cidreira.
# Retrieving Results for Index 121: mahadday weyne.
# Retrieving Results for Index 121: mahadday weyne.
# Retrieving Results for Index 122: puerto quijarro.
# Retrieving Results for Index 123: castro.
# Retrieving Results for Index 124: sentyabrskiy.
# Retrieving Results for Index 124: sentyabrskiy.
# Retrieving Results for Index 125: attawapiskat.
# Retrieving Results for Index 125: attawapiskat.
# Retrieving Results for Index 126: ixtapa.
# Retrieving Results for Index 127: san patricio.
# Retrieving Results for Index 128: bredasdorp.
# Retrieving Results for Index 129: gyanpur.
# Retrieving Results for Index 130: imbituba.
# Retrieving Results for Index 131: upernavik.
# Retrieving Results for Index 132: vardo.
# Retrieving Results for Index 133: misratah.
# Retrieving Results for Index 134: yashalta.
# Retrieving Results for Index 135: kahului.
# Retrieving Results for Index 136: assomada.
# Retrieving Results for Index 137: mount gambier.
# Retrieving Results for Index 138: georgetown.
# Retrieving Results for Index 139: peniche.
# Retrieving Results for Index 140: provideniya.
# Retrieving Results for Index 141: alofi.
# Retrieving Results for Index 142: nanortalik.
# Retrieving Results for Index 143: beaufort.
# Retrieving Results for Index 144: boyabat.
# Retrieving Results for Index 145: sabha.
# Retrieving Results for Index 146: evensk.
# Retrieving Results for Index 147: pevek.
# Retrieving Results for Index 148: santa cruz de tenerife.
# Retrieving Results for Index 149: goderich.
# Retrieving Results for Index 150: moron.
# Retrieving Results for Index 151: saskylakh.
# Retrieving Results for Index 152: mys shmidta.
# Retrieving Results for Index 152: mys shmidta.
# Retrieving Results for Index 153: anloga.
# Retrieving Results for Index 154: saint-philippe.
# Retrieving Results for Index 155: beringovskiy.
# Retrieving Results for Index 156: roebourne.
# Retrieving Results for Index 157: whitehorse.
# Retrieving Results for Index 158: vanimo.
# Retrieving Results for Index 159: zhezkazgan.
# Retrieving Results for Index 160: anori.
# Retrieving Results for Index 161: bacuit.
# Retrieving Results for Index 161: bacuit.
# Retrieving Results for Index 162: ponta delgada.
# Retrieving Results for Index 163: cheuskiny.
# Retrieving Results for Index 163: cheuskiny.
# Retrieving Results for Index 164: sechura.
# Retrieving Results for Index 165: mantua.
# Retrieving Results for Index 166: sinnamary.
# Retrieving Results for Index 167: narsaq.
# Retrieving Results for Index 168: zhigalovo.
# Retrieving Results for Index 169: nshamba.
# Retrieving Results for Index 170: tabuk.
# Retrieving Results for Index 171: nikolsk.
# Retrieving Results for Index 172: megion.
# Retrieving Results for Index 173: marsa matruh.
# Retrieving Results for Index 174: tiarei.
# Retrieving Results for Index 175: milkovo.
# Retrieving Results for Index 176: jumla.
# Retrieving Results for Index 177: plyussa.
# Retrieving Results for Index 178: malindi.
# Retrieving Results for Index 179: maarianhamina.
# Retrieving Results for Index 180: mayo.
# Retrieving Results for Index 181: mount isa.
# Retrieving Results for Index 182: bengkulu.
# Retrieving Results for Index 183: olafsvik.
# Retrieving Results for Index 184: faanui.
# Retrieving Results for Index 185: maykain.
# Retrieving Results for Index 185: maykain.
# Retrieving Results for Index 186: bethel.
# Retrieving Results for Index 187: nikolskoye.
# Retrieving Results for Index 188: pacific grove.
# Retrieving Results for Index 189: bubaque.
# Retrieving Results for Index 190: barrow.
# Retrieving Results for Index 191: pangnirtung.
# Retrieving Results for Index 192: bandarbeyla.
# Retrieving Results for Index 193: goreloye.
# Retrieving Results for Index 194: san cristobal.
# Retrieving Results for Index 195: grande-riviere.
# Retrieving Results for Index 195: grande-riviere.
# Retrieving Results for Index 196: prince rupert.
# Retrieving Results for Index 197: cayenne.
# Retrieving Results for Index 198: srikakulam.
# Retrieving Results for Index 199: amderma.
# Retrieving Results for Index 199: amderma.
# Retrieving Results for Index 200: opuwo.
# Retrieving Results for Index 201: severo-kurilsk.
# Retrieving Results for Index 202: saint anthony.
# Retrieving Results for Index 203: hasaki.
# Retrieving Results for Index 204: rungata.
# Retrieving Results for Index 204: rungata.
# Retrieving Results for Index 205: okhtyrka.
# Retrieving Results for Index 206: kilindoni.
# Retrieving Results for Index 207: nizhneyansk.
# Retrieving Results for Index 207: nizhneyansk.
# Retrieving Results for Index 208: kalaiya.
# Retrieving Results for Index 209: rabak.
# Retrieving Results for Index 210: egvekinot.
# Retrieving Results for Index 211: guadalupe y calvo.
# Retrieving Results for Index 212: laguna.
# Retrieving Results for Index 213: lake ridge.
# Retrieving Results for Index 214: hithadhoo.
# Retrieving Results for Index 215: sur.
# Retrieving Results for Index 216: port alfred.
# Retrieving Results for Index 217: tazovskiy.
# Retrieving Results for Index 218: kavieng.
# Retrieving Results for Index 219: port hardy.
# Retrieving Results for Index 220: tsihombe.
# Retrieving Results for Index 220: tsihombe.
# Retrieving Results for Index 221: betare oya.
# Retrieving Results for Index 222: xunchang.
# Retrieving Results for Index 223: ingham.
# Retrieving Results for Index 224: moerai.
# Retrieving Results for Index 225: husavik.
# Retrieving Results for Index 226: henties bay.
# Retrieving Results for Index 227: lerwick.
# Retrieving Results for Index 228: baruun-urt.
# Retrieving Results for Index 229: saint-augustin.
# Retrieving Results for Index 230: finschhafen.
# Retrieving Results for Index 231: yashkino.
# Retrieving Results for Index 232: airai.
# Retrieving Results for Index 233: sakakah.
# Retrieving Results for Index 234: vostok.
# Retrieving Results for Index 235: barentsburg.
# Retrieving Results for Index 235: barentsburg.
# Retrieving Results for Index 236: kamaishi.
# Retrieving Results for Index 237: hofn.
# Retrieving Results for Index 238: thai nguyen.
# Retrieving Results for Index 239: lorengau.
# Retrieving Results for Index 240: hienghene.
# Retrieving Results for Index 241: khash.
# Retrieving Results for Index 242: portland.
# Retrieving Results for Index 243: mayskiy.
# Retrieving Results for Index 244: praia.
# Retrieving Results for Index 245: gangotri.
# Retrieving Results for Index 245: gangotri.
# Retrieving Results for Index 246: weihe.
# Retrieving Results for Index 247: vila franca do campo.
# Retrieving Results for Index 248: outjo.
# Retrieving Results for Index 249: tuatapere.
# Retrieving Results for Index 250: pathein.
# Retrieving Results for Index 251: jiayuguan.
# Retrieving Results for Index 252: sosnovo-ozerskoye.
# Retrieving Results for Index 253: phun phin.
# Retrieving Results for Index 253: phun phin.
# Retrieving Results for Index 254: salalah.
# Retrieving Results for Index 255: saldanha.
# Retrieving Results for Index 256: ginir.
# Retrieving Results for Index 257: crab hill.
# Retrieving Results for Index 257: crab hill.
# Retrieving Results for Index 258: kudahuvadhoo.
# Retrieving Results for Index 259: salinas.
# Retrieving Results for Index 260: taruma.
# Retrieving Results for Index 261: cortland.
# Retrieving Results for Index 262: belushya guba.
# Retrieving Results for Index 262: belushya guba.
# Retrieving Results for Index 263: marsh harbour.
# Retrieving Results for Index 264: roma.
# Retrieving Results for Index 265: kamenskoye.
# Retrieving Results for Index 265: kamenskoye.
# Retrieving Results for Index 266: chara.
# Retrieving Results for Index 267: kungurtug.
# Retrieving Results for Index 268: burnie.
# Retrieving Results for Index 269: polaniec.
# Retrieving Results for Index 270: labuhan.
# Retrieving Results for Index 271: kabo.
# Retrieving Results for Index 272: nisia floresta.
# Retrieving Results for Index 273: nara.
# Retrieving Results for Index 274: matara.
# Retrieving Results for Index 275: krasnyy tekstilshchik.
# Retrieving Results for Index 275: krasnyy tekstilshchik.
# Retrieving Results for Index 276: blackwater.
# Retrieving Results for Index 277: skibby.
# Retrieving Results for Index 278: la ronge.
# Retrieving Results for Index 279: katobu.
# Retrieving Results for Index 280: zelenoborskiy.
# Retrieving Results for Index 281: vaitupu.
# Retrieving Results for Index 281: vaitupu.
# Retrieving Results for Index 282: hambantota.
# Retrieving Results for Index 283: santa cruz.
# Retrieving Results for Index 284: vao.
# Retrieving Results for Index 285: gander.
# Retrieving Results for Index 286: nichinan.
# Retrieving Results for Index 287: baykit.
# Retrieving Results for Index 288: dickinson.
# Retrieving Results for Index 289: klaksvik.
# Retrieving Results for Index 290: brigantine.
# Retrieving Results for Index 291: sao filipe.
# Retrieving Results for Index 292: east london.
# Retrieving Results for Index 293: whakatane.
# Retrieving Results for Index 294: oranjemund.
# Retrieving Results for Index 295: brae.
# Retrieving Results for Index 296: nidzica.
# Retrieving Results for Index 297: severo-yeniseyskiy.
# Retrieving Results for Index 298: mergui.
# Retrieving Results for Index 298: mergui.
# Retrieving Results for Index 299: susanville.
# Retrieving Results for Index 300: babanusah.
# Retrieving Results for Index 300: babanusah.
# Retrieving Results for Index 301: moose factory.
# Retrieving Results for Index 302: necochea.
# Retrieving Results for Index 303: acarau.
# Retrieving Results for Index 304: vung tau.
# Retrieving Results for Index 305: rudnogorsk.
# Retrieving Results for Index 306: avarua.
# Retrieving Results for Index 307: along.
# Retrieving Results for Index 308: paradwip.
# Retrieving Results for Index 308: paradwip.
# Retrieving Results for Index 309: cayhagan.
# Retrieving Results for Index 310: poronaysk.
# Retrieving Results for Index 311: akonolinga.
# Retrieving Results for Index 312: ofaqim.
# Retrieving Results for Index 313: ambilobe.
# Retrieving Results for Index 314: lyngdal.
# Retrieving Results for Index 315: bathsheba.
# Retrieving Results for Index 316: ngukurr.
# Retrieving Results for Index 316: ngukurr.
# Retrieving Results for Index 317: dolbeau.
# Retrieving Results for Index 317: dolbeau.
# Retrieving Results for Index 318: bambous virieux.
# Retrieving Results for Index 319: meulaboh.
# Retrieving Results for Index 320: ulaangom.
# Retrieving Results for Index 321: tenenkou.
# Retrieving Results for Index 322: nampula.
# Retrieving Results for Index 323: hovd.
# Retrieving Results for Index 324: bandar-e lengeh.
# Retrieving Results for Index 325: grand-santi.
# Retrieving Results for Index 326: udachnyy.
# Retrieving Results for Index 327: ayan.
# Retrieving Results for Index 328: serik.
# Retrieving Results for Index 329: hirara.
# Retrieving Results for Index 330: wanning.
# Retrieving Results for Index 331: camocim.
# Retrieving Results for Index 332: andros town.
# Retrieving Results for Index 333: russell.
# Retrieving Results for Index 334: itoman.
# Retrieving Results for Index 335: lahij.
# Retrieving Results for Index 336: tromso.
# Retrieving Results for Index 337: panalingaan.
# Retrieving Results for Index 338: meadow lake.
# Retrieving Results for Index 339: ahuimanu.
# Retrieving Results for Index 340: phangnga.
# Retrieving Results for Index 341: luganville.
# Retrieving Results for Index 342: maumere.
# Retrieving Results for Index 343: bridgeton.
# Retrieving Results for Index 344: chepareria.
# Retrieving Results for Index 345: souillac.
# Retrieving Results for Index 346: kantang.
# Retrieving Results for Index 347: paita.
# Retrieving Results for Index 348: sorland.
# Retrieving Results for Index 349: strezhevoy.
# Retrieving Results for Index 350: kuantan.
# Retrieving Results for Index 351: pozoblanco.
# Retrieving Results for Index 352: urumqi.
# Retrieving Results for Index 353: hefei.
# Retrieving Results for Index 354: mersing.
# Retrieving Results for Index 355: calolbon.
# Retrieving Results for Index 356: gurupi.
# Retrieving Results for Index 357: metkovic.
# Retrieving Results for Index 358: lagunas.
# Retrieving Results for Index 359: andalan.
# Retrieving Results for Index 360: sao jose do belmonte.
# Retrieving Results for Index 361: half moon bay.
# Retrieving Results for Index 362: thiers.
# Retrieving Results for Index 363: namibe.
# Retrieving Results for Index 364: battle creek.
# Retrieving Results for Index 365: dvinskoy.
# Retrieving Results for Index 366: coihaique.
# Retrieving Results for Index 367: san rafael.
# Retrieving Results for Index 368: kota belud.
# Retrieving Results for Index 369: ust-maya.
# Retrieving Results for Index 370: umm ruwabah.
# Retrieving Results for Index 370: umm ruwabah.
# Retrieving Results for Index 371: kegayli.
# Retrieving Results for Index 371: kegayli.
# Retrieving Results for Index 372: asfi.
# Retrieving Results for Index 373: puerto escondido.
# Retrieving Results for Index 374: kruisfontein.
# Retrieving Results for Index 375: los llanos de aridane.
# Retrieving Results for Index 376: nouadhibou.
# Retrieving Results for Index 377: deputatskiy.
# Retrieving Results for Index 378: mweka.
# Retrieving Results for Index 379: havre-saint-pierre.
# Retrieving Results for Index 380: savannah bight.
# Retrieving Results for Index 381: hihifo.
# Retrieving Results for Index 381: hihifo.
# Retrieving Results for Index 382: fairbanks.
# Retrieving Results for Index 383: fonseca.
# Retrieving Results for Index 384: avera.
# Retrieving Results for Index 385: santander.
# Retrieving Results for Index 386: mandalgovi.
# Retrieving Results for Index 387: itarema.
# Retrieving Results for Index 388: san quintin.
# Retrieving Results for Index 389: oksfjord.
# Retrieving Results for Index 390: novyy urengoy.
# Retrieving Results for Index 391: maridi.
# Retrieving Results for Index 392: pisco.
# Retrieving Results for Index 393: louisbourg.
# Retrieving Results for Index 393: louisbourg.
# Retrieving Results for Index 394: bonthe.
# Retrieving Results for Index 395: kizukuri.
# Retrieving Results for Index 396: berlevag.
# Retrieving Results for Index 397: cuenca.
# Retrieving Results for Index 398: gornopravdinsk.
# Retrieving Results for Index 399: zaysan.
# Retrieving Results for Index 400: alice springs.
# Retrieving Results for Index 401: uvat.
# Retrieving Results for Index 402: kalmunai.
# Retrieving Results for Index 403: atherton.
# Retrieving Results for Index 404: nouakchott.
# Retrieving Results for Index 405: rypefjord.
# Retrieving Results for Index 406: victor harbor.
# Retrieving Results for Index 407: katherine.
# Retrieving Results for Index 408: porto velho.
# Retrieving Results for Index 409: nome.
# Retrieving Results for Index 410: takoradi.
# Retrieving Results for Index 411: mkushi.
# Retrieving Results for Index 412: silver city.
# Retrieving Results for Index 413: silvia.
# Retrieving Results for Index 414: gat.
# Retrieving Results for Index 415: kwinana.
# Retrieving Results for Index 416: grindavik.
# Retrieving Results for Index 417: baghdad.
# Retrieving Results for Index 418: zhitikara.
# Retrieving Results for Index 418: zhitikara.
# Retrieving Results for Index 419: yantal.
# Retrieving Results for Index 420: port blair.
# Retrieving Results for Index 421: belmonte.
# Retrieving Results for Index 422: icod de los vinos.
# Retrieving Results for Index 423: lata.
# Retrieving Results for Index 424: tambovka.
# Retrieving Results for Index 425: belaya kholunitsa.
# Retrieving Results for Index 426: high rock.
# Retrieving Results for Index 427: karratha.
# Retrieving Results for Index 428: juruti.
# Retrieving Results for Index 429: linkoping.
# Retrieving Results for Index 430: saryshagan.
# Retrieving Results for Index 430: saryshagan.
# Retrieving Results for Index 431: the valley.
# Retrieving Results for Index 432: sisimiut.
# Retrieving Results for Index 433: imamoglu.
# Retrieving Results for Index 434: raytown.
# Retrieving Results for Index 435: iskateley.
# Retrieving Results for Index 436: kodinar.
# Retrieving Results for Index 437: tiksi.
# Retrieving Results for Index 438: ulety.
# Retrieving Results for Index 439: rochegda.
# Retrieving Results for Index 440: kununurra.
# Retrieving Results for Index 441: nau.
# Retrieving Results for Index 442: sao felix do xingu.
# Retrieving Results for Index 443: ulaanbaatar.
# Retrieving Results for Index 444: santa cruz del sur.
# Retrieving Results for Index 445: eureka.
# Retrieving Results for Index 446: sorong.
# Retrieving Results for Index 447: sitka.
# Retrieving Results for Index 448: iqaluit.
# Retrieving Results for Index 449: inuvik.
# Retrieving Results for Index 450: birao.
# Retrieving Results for Index 451: tumannyy.
# Retrieving Results for Index 451: tumannyy.
# Retrieving Results for Index 452: poum.
# Retrieving Results for Index 453: santa luzia.
# Retrieving Results for Index 454: bendigo.
# Retrieving Results for Index 455: seymchan.
# Retrieving Results for Index 456: kjollefjord.
# Retrieving Results for Index 457: kisangani.
# Retrieving Results for Index 458: gerede.
# Retrieving Results for Index 459: ahipara.
# Retrieving Results for Index 460: nacala.
# Retrieving Results for Index 461: richards bay.
# Retrieving Results for Index 462: roxana.
# Retrieving Results for Index 463: san alberto.
# Retrieving Results for Index 464: kysyl-syr.
# Retrieving Results for Index 465: daru.
# Retrieving Results for Index 466: nizhniy tsasuchey.
# Retrieving Results for Index 467: mumford.
# Retrieving Results for Index 468: isangel.
# Retrieving Results for Index 469: talnakh.
# Retrieving Results for Index 470: mahebourg.
# Retrieving Results for Index 471: okhotsk.
# Retrieving Results for Index 472: kabinda.
# Retrieving Results for Index 473: ko samui.
# Retrieving Results for Index 474: sault sainte marie.
# Retrieving Results for Index 475: nizwa.
# Retrieving Results for Index 476: mangan.
# Retrieving Results for Index 477: kaeo.
# Retrieving Results for Index 478: kyra.
# Retrieving Results for Index 479: muzquiz.
# Retrieving Results for Index 479: muzquiz.
# Retrieving Results for Index 480: juneau.
# Retrieving Results for Index 481: valparaiso.
# Retrieving Results for Index 482: chokurdakh.
# Retrieving Results for Index 483: joshimath.
# Retrieving Results for Index 484: lobito.
# Retrieving Results for Index 485: warora.
# Retrieving Results for Index 486: dosso.
# Retrieving Results for Index 487: nicoya.
# Retrieving Results for Index 488: guliston.
# Retrieving Results for Index 489: broome.
# Retrieving Results for Index 490: buzdyak.
# Retrieving Results for Index 491: borgarnes.
# Retrieving Results for Index 492: labuan.
# Retrieving Results for Index 493: vama buzaului.
# Retrieving Results for Index 493: vama buzaului.
# Retrieving Results for Index 494: nattam.
# Retrieving Results for Index 495: namatanai.
# Retrieving Results for Index 496: aklavik.
# Retrieving Results for Index 497: capinopolis.
# Retrieving Results for Index 498: shenjiamen.
# Retrieving Results for Index 499: anadyr.
# Retrieving Results for Index 500: torquay.
# Retrieving Results for Index 501: savalou.
# Retrieving Results for Index 502: mardin.
# Retrieving Results for Index 503: lubumbashi.
# Retrieving Results for Index 504: nova prata.
# Retrieving Results for Index 505: cam pha.
# Retrieving Results for Index 505: cam pha.
# Retrieving Results for Index 506: gushikawa.
# Retrieving Results for Index 507: menongue.
# Retrieving Results for Index 508: vibo valentia.
# Retrieving Results for Index 509: tubruq.
# Retrieving Results for Index 509: tubruq.
# Retrieving Results for Index 510: igrim.
# Retrieving Results for Index 511: saint-pierre.
# Retrieving Results for Index 512: migori.
# Retrieving Results for Index 513: kerema.
# Retrieving Results for Index 514: lavrentiya.
# Retrieving Results for Index 515: shache.
# Retrieving Results for Index 516: prainha.
# Retrieving Results for Index 517: yar-sale.
# Retrieving Results for Index 518: tual.
# Retrieving Results for Index 519: ellensburg.
# Retrieving Results for Index 520: davila.
# Retrieving Results for Index 521: udobnaya.
# Retrieving Results for Index 522: roald.
# Retrieving Results for Index 523: taiyuan.
# Retrieving Results for Index 524: tiznit.
# Retrieving Results for Index 525: esmeralda.
# Retrieving Results for Index 526: nosy varika.
# Retrieving Results for Index 527: banatsko novo selo.
# Retrieving Results for Index 528: sangueya.
# Retrieving Results for Index 529: tezu.
# Retrieving Results for Index 530: sao joao da barra.
# Retrieving Results for Index 531: smolenka.
# Retrieving Results for Index 532: asau.
# Retrieving Results for Index 533: bereda.
# Retrieving Results for Index 534: ostrovnoy.
# Retrieving Results for Index 535: meyungs.
# Retrieving Results for Index 535: meyungs.
# Retrieving Results for Index 536: pershotravneve.
# Retrieving Results for Index 537: pontianak.
# Retrieving Results for Index 538: kamenka.
# Retrieving Results for Index 539: lethem.
# Retrieving Results for Index 540: delijan.
# Retrieving Results for Index 541: santa maria.
# Retrieving Results for Index 542: khorixas.
# Retrieving Results for Index 543: bassila.
# Retrieving Results for Index 544: bermeo.
# Retrieving Results for Index 545: norden.
# Retrieving Results for Index 546: miracema do tocantins.
# Retrieving Results for Index 547: saint-francois.
# Retrieving Results for Index 548: high level.
# Retrieving Results for Index 549: tecoanapa.
# Retrieving Results for Index 550: the pas.
# Retrieving Results for Index 551: buin.
# Retrieving Results for Index 552: palembang.
# Retrieving Results for Index 553: waipawa.
# Retrieving Results for Index 554: huarmey.
# Retrieving Results for Index 555: nantucket.
# Retrieving Results for Index 556: colmenar viejo.
# Retrieving Results for Index 557: iberia.
# Retrieving Results for Index 558: tabas.
# Retrieving Results for Index 559: tambura.
# Retrieving Results for Index 560: kavaratti.
# Retrieving Results for Index 561: szomod.
# Retrieving Results for Index 562: letlhakeng.
# Retrieving Results for Index 563: bagdarin.
# Retrieving Results for Index 564: dauriya.
# Retrieving Results for Index 565: foki.
# Retrieving Results for Index 566: pozo colorado.
# Retrieving Results for Index 567: norman wells.
# Retrieving Results for Index 568: tucuma.
# Retrieving Results for Index 569: pocatello.
# Retrieving Results for Index 570: rincon.
# Retrieving Results for Index 571: falun.
# Retrieving Results for Index 572: ouadda.
# Retrieving Results for Index 573: celestun.
# Retrieving Results for Index 574: ilulissat.
# Retrieving Results for Index 575: quelimane.
# Retrieving Results for Index 576: babynino.
# Retrieving Results for Index 577: artvin.
# Retrieving Results for Index 578: abu samrah.
# Retrieving Results for Index 579: bagaha.
# Retrieving Results for Index 580: viedma.
# Retrieving Results for Index 581: angoche.
# Retrieving Results for Index 582: chengmai.
# Retrieving Results for Index 582: chengmai.
# Retrieving Results for Index 583: pulandian.
# Retrieving Results for Index 584: ballinasloe.
# Retrieving Results for Index 585: plainview.
# Retrieving Results for Index 586: korla.
# Retrieving Results for Index 587: kikwit.
# Retrieving Results for Index 588: manokwari.
# Retrieving Results for Index 589: veraval.
# Retrieving Results for Index 590: atambua.
# Retrieving Results for Index 591: sorvag.
# Retrieving Results for Index 591: sorvag.
# Retrieving Results for Index 592: bukama.
# Retrieving Results for Index 593: hvide sande.
# Retrieving Results for Index 594: springbok.
# Retrieving Results for Index 595: campbell river.
# Retrieving Results for Index 596: clarence town.
# Retrieving Results for Index 597: sovetskiy.
# Retrieving Results for Index 598: rocha.
# Retrieving Results for Index 599: yeppoon.
# Retrieving Results for Index 600: taltal.
# Retrieving Results for Index 601: poso.
# Retrieving Results for Index 602: lara.
# Retrieving Results for Index 603: saint-louis.
# Retrieving Results for Index 604: maceio.
# Retrieving Results for Index 605: kabalo.
# Retrieving Results for Index 606: hami.
# Retrieving Results for Index 607: auki.
# Retrieving Results for Index 608: qaqortoq.
# Retrieving Results for Index 609: bilma.
# Retrieving Results for Index 610: paragominas.
# Retrieving Results for Index 611: stornoway.
# Retrieving Results for Index 612: omboue.
# Retrieving Results for Index 613: clyde river.
# Retrieving Results for Index 614: leningradskiy.
# Retrieving Results for Index 615: mallapuram.
# Retrieving Results for Index 616: daura.
# Retrieving Results for Index 617: zhangye.
# Retrieving Results for Index 618: kieta.
# Retrieving Results for Index 619: port pirie.
# Retrieving Results for Index 620: palora.
# Retrieving Results for Index 621: martinez.
# Retrieving Results for Index 622: nabire.
# Retrieving Results for Index 623: yaan.
# Retrieving Results for Index 624: jawhar.
# Retrieving Results for Index 625: san francisco de coray.
# Retrieving Results for Index 626: wahiawa.
# Retrieving Results for Index 627: calvia.

# %%
cities_df
# Out:
#                      Cities Forecast  Cloudiness (%) Country  \
# 0                     ancud    Clear             0.0      CL
# 1                    dalvik    Clear             0.0      IS
# 2             srednekolymsk   Clouds            94.0      RU
# 3                vila velha     Rain            90.0      BR
# 4                   changtu    Clear             8.0      CN
# ..                      ...      ...             ...     ...
# 623                    yaan     Rain             5.0      NG
# 624                  jawhar    Clear             9.0      SO
# 625  san francisco de coray    Clear             8.0      HN
# 626                 wahiawa  Drizzle            20.0      US
# 627                  calvia    Clear             0.0      ES
#
#                    Date  Humidity    Lat     Lng  Max Temperature (F)  \
# 0   2020-04-08 15:59:09      31.0 -41.87  -73.82                73.40
# 1   2020-04-08 16:05:04      74.0  65.97  -18.53                28.40
# 2   2020-04-08 15:57:52      91.0  67.45  153.68                 0.14
# 3   2020-04-08 16:04:15      94.0 -20.33  -40.29                72.00
# 4   2020-04-08 16:05:04      90.0  42.78  124.10                32.25
# ..                  ...       ...    ...     ...                  ...
# 623 2020-04-08 16:00:57      56.0   7.38    8.57                85.86
# 624 2020-04-08 16:05:37      65.0   2.78   45.50                81.54
# 625 2020-04-08 16:05:37      32.0  13.66  -87.53                96.80
# 626 2020-04-08 16:02:57      69.0  21.50 -158.02                78.80
# 627 2020-04-08 16:05:37      72.0  39.57    2.51                60.01
#
#      Wind Speed (mph)
# 0                8.05
# 1                2.24
# 2                9.48
# 3               16.11
# 4                5.39
# ..                ...
# 623              6.62
# 624             10.16
# 625              6.93
# 626              6.93
# 627              1.12
#
# [628 rows x 10 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.columns
cities_df.to_csv (r'city_weather_dataframe.csv', index = False, header=True)

# %%
cities_df
# Out:
#                      Cities Forecast  Cloudiness (%) Country  \
# 0                     ancud    Clear             0.0      CL
# 1                    dalvik    Clear             0.0      IS
# 2             srednekolymsk   Clouds            94.0      RU
# 3                vila velha     Rain            90.0      BR
# 4                   changtu    Clear             8.0      CN
# ..                      ...      ...             ...     ...
# 623                    yaan     Rain             5.0      NG
# 624                  jawhar    Clear             9.0      SO
# 625  san francisco de coray    Clear             8.0      HN
# 626                 wahiawa  Drizzle            20.0      US
# 627                  calvia    Clear             0.0      ES
#
#                    Date  Humidity    Lat     Lng  Max Temperature (F)  \
# 0   2020-04-08 15:59:09      31.0 -41.87  -73.82                73.40
# 1   2020-04-08 16:05:04      74.0  65.97  -18.53                28.40
# 2   2020-04-08 15:57:52      91.0  67.45  153.68                 0.14
# 3   2020-04-08 16:04:15      94.0 -20.33  -40.29                72.00
# 4   2020-04-08 16:05:04      90.0  42.78  124.10                32.25
# ..                  ...       ...    ...     ...                  ...
# 623 2020-04-08 16:00:57      56.0   7.38    8.57                85.86
# 624 2020-04-08 16:05:37      65.0   2.78   45.50                81.54
# 625 2020-04-08 16:05:37      32.0  13.66  -87.53                96.80
# 626 2020-04-08 16:02:57      69.0  21.50 -158.02                78.80
# 627 2020-04-08 16:05:37      72.0  39.57    2.51                60.01
#
#      Wind Speed (mph)
# 0                8.05
# 1                2.24
# 2                9.48
# 3               16.11
# 4                5.39
# ..                ...
# 623              6.62
# 624             10.16
# 625              6.93
# 626              6.93
# 627              1.12
#
# [628 rows x 10 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# print(cities_df["Max Temperature (F)"])
# print(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Max Temperature (F)"])
plt.title("Latitude of Cities vs Max Temperature in Farenheit")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Max Temperature (F)"].min() - 10, cities_df["Max Temperature (F)"].max() + 10)
plt.grid(True, which = "major")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# print(cities_df["Humidity"])
# print(cities_df["Lat"])

plt.scatter(cities_df["Lat"], cities_df["Humidity"])
plt.title("Latitude of Cities vs Percent Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Humidity"].min() - 10, cities_df["Humidity"].max() + 10)
plt.grid(True, which = "major")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# print(cities_df["Lat"])
# print(cities_df["Cloudiness (%)"])

plt.scatter(cities_df["Lat"], cities_df["Cloudiness (%)"])
plt.title("Latitude of Cities vs Percent Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Cloudiness (%)"].min() - 10, cities_df["Cloudiness (%)"].max() + 10)
plt.grid(True, which = "major")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Wind Speed (mph)"])
plt.title("Latitude of Cities vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Wind Speed (mph)"].min() - 10, cities_df["Wind Speed (mph)"].max() + 10)
plt.grid(True, which = "major")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Take information from cities_df and transfer to another data frame

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df= cities_df.loc[cities_df['Lat'] >= 0, :]
southern_df = cities_df.loc[cities_df['Lat'] < 0, :]
# northern_df
# southern_df

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Max Temperature (F)"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere - Max Temperature vs Latitude")

slope_n1, intercept_n1, rvalue_n1, pvalue_n1, stderr_n1 = linregress(northern_df["Lat"], northern_df["Max Temperature (F)"])
lin_req_annotate = str(f"y = {round(slope_n1,ndigits=2)}x + {round(intercept_n1,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n1 + slope_n1*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate, (0,-10))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n1**2,ndigits = 3)}')
# Out:
# R-squared is 0.759

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Max Temperature (F)"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere - Max Temperature vs Latitude")

slope_s1, intercept_s1, rvalue_s1, pvalue_s1, stderr_s1 = linregress(southern_df["Lat"], southern_df["Max Temperature (F)"])
lin_req_annotate2 = str(f"y = {round(slope_s1, ndigits=2)}x + {round(intercept_s1,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s1 + slope_s1*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate2, (-25,50))
plt.legend()
plt.show()

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hemisphere - Max Temperature vs Humidity")

slope_n2, intercept_n2, rvalue_n2, pvalue_n2, stderr_n2 = linregress(northern_df["Lat"], northern_df["Humidity"])
lin_req_annotate3 = str(f"y = {round(slope_n2,ndigits=2)}x + {round(intercept_n2,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n2 + slope_n2*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate3, (55,15))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n2**2,ndigits = 3)}')
# Out:
# R-squared is 0.057

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity vs Latitude")

slope_s2, intercept_s2, rvalue_s2, pvalue_s2, stderr_s2 = linregress(southern_df["Lat"], southern_df["Humidity"])
lin_req_annotate4 = str(f"y = {round(slope_s2, ndigits=2)}x + {round(intercept_s2,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s2 + slope_s2*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate4, (-55,50))
plt.legend()
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Cloudiness (%)"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Northern Hemisphere - Cloudiness % vs Latitude")

slope_n3, intercept_n3, rvalue_n3, pvalue_n3, stderr_n3 = linregress(northern_df["Lat"], northern_df["Cloudiness (%)"])
lin_req_annotate4 = str(f"y = {round(slope_n3,ndigits=2)}x + {round(intercept_n3,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n3 + slope_n3*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate4, (60,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n3**2,ndigits = 3)}')
# Out:
# R-squared is 0.008

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Cloudiness (%)"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Southern Hemisphere - Cloudiness % vs Latitude")

slope_s3, intercept_s3, rvalue_s3, pvalue_s3, stderr_s3 = linregress(southern_df["Lat"], southern_df["Cloudiness (%)"])
lin_req_annotate5 = str(f"y = {round(slope_s3,ndigits=2)}x + {round(intercept_s3,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s3 + slope_s3*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate5, (-52,25))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_s3**2,ndigits = 3)}')
# Out:
# R-squared is 0.067

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Wind Speed (mph)"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed vs Latitude")

slope_n4, intercept_n4, rvalue_n4, pvalue_n4, stderr_n4 = linregress(northern_df["Lat"], northern_df["Wind Speed (mph)"])
lin_req_annotate6 = str(f"y = {round(slope_n4,ndigits=2)}x + {round(intercept_n4,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n4 + slope_n4*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate6, (60,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n4**2,ndigits = 3)}')
# Out:
# R-squared is 0.011

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Wind Speed (mph)"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed vs Latitude")

slope_s4, intercept_s4, rvalue_s4, pvalue_s4, stderr_s4 = linregress(southern_df["Lat"], southern_df["Wind Speed (mph)"])
lin_req_annotate7 = str(f"y = {round(slope_s4,ndigits=2)}x + {round(intercept_s4,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s4 + slope_s4*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate7, (-50,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_s4**2,ndigits = 3)}')
# Out:
# R-squared is 0.051
