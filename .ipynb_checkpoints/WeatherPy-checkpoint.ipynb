# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities_df = pd.DataFrame(cities)
cities_df.rename(columns={0:"Cities"}, inplace = True)
cities_df
# Out:
#              Cities
# 0              teya
# 1             korla
# 2           aklavik
# 3      attawapiskat
# 4    ribeira grande
# ..              ...
# 621     itacoatiara
# 622          laguna
# 623            nuuk
# 624         del rio
# 625          beloha
#
# [626 rows x 1 columns]

# %%
# cities_df["Cloudiness"] = ""
# cities_df["Country"] = ""
# cities_df["Date"] = ""
# cities_df["Humidity"]=""
# cities_df["Lat"]=""
# cities_df["Lng"]=""
# cities_df["Max Temperature (F)"]=""
# cities_df["Wind Speed (mph)"]=""
# cities_df.head(10)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
for index, row in cities_df.iterrows():

    cities_df.loc[cities_df.index, "Cities"]


# API Request below has been proven successful
    weather_url = "http://api.openweathermap.org/data/2.5/weather?q="+cities[index]+"&units=imperial&appid="+weather_api_key
    data_wea = requests.get(weather_url)
    response = data_wea.json()
#     print(response)
#     print(json.dumps(response, indent = 4))
    try:
        cities_df.loc[index,"Forecast"] = response["weather"][0]["main"]
        cities_df.loc[index, "Cloudiness (%)"] = response["clouds"]["all"]
        cities_df.loc[index,"Country"] = response["sys"]["country"]
        cities_df.loc[index,"Date"] = datetime.fromtimestamp(response["dt"])
        cities_df.loc[index,"Humidity"] = response["main"]["humidity"]
        cities_df.loc[index,"Lat"] = response["coord"]["lat"]
        cities_df.loc[index,"Lng"] = response["coord"]["lon"]
        cities_df.loc[index,"Max Temperature (F)"] = response["main"]["temp_max"]
        cities_df.loc[index,"Wind Speed (mph)"]=response["wind"]["speed"]

    except KeyError:
        print(f"Retrieving Results for Index {index}: {cities[index]}.")
    print(f"Retrieving Results for Index {index}: {cities[index]}.")
# Out:
# Retrieving Results for Index 0: teya.
# Retrieving Results for Index 1: korla.
# Retrieving Results for Index 2: aklavik.
# Retrieving Results for Index 3: attawapiskat.
# Retrieving Results for Index 3: attawapiskat.
# Retrieving Results for Index 4: ribeira grande.
# Retrieving Results for Index 5: kodiak.
# Retrieving Results for Index 6: tsihombe.
# Retrieving Results for Index 6: tsihombe.
# Retrieving Results for Index 7: mataura.
# Retrieving Results for Index 8: grand river south east.
# Retrieving Results for Index 8: grand river south east.
# Retrieving Results for Index 9: hermanus.
# Retrieving Results for Index 10: amderma.
# Retrieving Results for Index 10: amderma.
# Retrieving Results for Index 11: plettenberg bay.
# Retrieving Results for Index 12: jamestown.
# Retrieving Results for Index 13: nabire.
# Retrieving Results for Index 14: desaguadero.
# Retrieving Results for Index 15: ushuaia.
# Retrieving Results for Index 16: dunedin.
# Retrieving Results for Index 17: mantua.
# Retrieving Results for Index 18: airai.
# Retrieving Results for Index 19: punta arenas.
# Retrieving Results for Index 20: illoqqortoormiut.
# Retrieving Results for Index 20: illoqqortoormiut.
# Retrieving Results for Index 21: victoria.
# Retrieving Results for Index 22: tumannyy.
# Retrieving Results for Index 22: tumannyy.
# Retrieving Results for Index 23: jalpan.
# Retrieving Results for Index 24: broome.
# Retrieving Results for Index 25: galle.
# Retrieving Results for Index 26: shenjiamen.
# Retrieving Results for Index 27: atocha.
# Retrieving Results for Index 28: new norfolk.
# Retrieving Results for Index 29: saint-denis.
# Retrieving Results for Index 30: mao.
# Retrieving Results for Index 31: anadyr.
# Retrieving Results for Index 32: jining.
# Retrieving Results for Index 33: mizdah.
# Retrieving Results for Index 34: cape town.
# Retrieving Results for Index 35: batagay.
# Retrieving Results for Index 36: pangnirtung.
# Retrieving Results for Index 37: vedaranniyam.
# Retrieving Results for Index 37: vedaranniyam.
# Retrieving Results for Index 38: alotau.
# Retrieving Results for Index 38: alotau.
# Retrieving Results for Index 39: bluff.
# Retrieving Results for Index 40: cidreira.
# Retrieving Results for Index 41: chapais.
# Retrieving Results for Index 42: saint-louis.
# Retrieving Results for Index 43: busselton.
# Retrieving Results for Index 44: samusu.
# Retrieving Results for Index 44: samusu.
# Retrieving Results for Index 45: georgetown.
# Retrieving Results for Index 46: umzimvubu.
# Retrieving Results for Index 46: umzimvubu.
# Retrieving Results for Index 47: misratah.
# Retrieving Results for Index 48: makakilo city.
# Retrieving Results for Index 49: nouadhibou.
# Retrieving Results for Index 50: barrow.
# Retrieving Results for Index 51: san policarpo.
# Retrieving Results for Index 52: marsh harbour.
# Retrieving Results for Index 53: ponta do sol.
# Retrieving Results for Index 54: pevek.
# Retrieving Results for Index 55: hithadhoo.
# Retrieving Results for Index 56: marcona.
# Retrieving Results for Index 56: marcona.
# Retrieving Results for Index 57: juquitiba.
# Retrieving Results for Index 58: bambous virieux.
# Retrieving Results for Index 59: imeni poliny osipenko.
# Retrieving Results for Index 60: fortuna.
# Retrieving Results for Index 61: qaanaaq.
# Retrieving Results for Index 62: albany.
# Retrieving Results for Index 63: kapaa.
# Retrieving Results for Index 64: severo-kurilsk.
# Retrieving Results for Index 65: vestmannaeyjar.
# Retrieving Results for Index 66: eston.
# Retrieving Results for Index 67: saskylakh.
# Retrieving Results for Index 68: rikitea.
# Retrieving Results for Index 69: vaini.
# Retrieving Results for Index 70: puerto ayora.
# Retrieving Results for Index 71: polson.
# Retrieving Results for Index 72: darhan.
# Retrieving Results for Index 73: hami.
# Retrieving Results for Index 74: bonavista.
# Retrieving Results for Index 75: north bend.
# Retrieving Results for Index 76: makaryev.
# Retrieving Results for Index 77: kropotkin.
# Retrieving Results for Index 78: bengkulu.
# Retrieving Results for Index 79: hobart.
# Retrieving Results for Index 80: mahebourg.
# Retrieving Results for Index 81: itaituba.
# Retrieving Results for Index 82: kattivakkam.
# Retrieving Results for Index 83: doume.
# Retrieving Results for Index 84: albuquerque.
# Retrieving Results for Index 85: bredasdorp.
# Retrieving Results for Index 86: yellowknife.
# Retrieving Results for Index 87: mar del plata.
# Retrieving Results for Index 88: tiksi.
# Retrieving Results for Index 89: coahuayana.
# Retrieving Results for Index 90: guerrero negro.
# Retrieving Results for Index 91: palabuhanratu.
# Retrieving Results for Index 91: palabuhanratu.
# Retrieving Results for Index 92: kamphaeng phet.
# Retrieving Results for Index 93: gardendale.
# Retrieving Results for Index 94: brewster.
# Retrieving Results for Index 95: husavik.
# Retrieving Results for Index 96: saint george.
# Retrieving Results for Index 97: vaitupu.
# Retrieving Results for Index 97: vaitupu.
# Retrieving Results for Index 98: coihaique.
# Retrieving Results for Index 99: zyryanka.
# Retrieving Results for Index 100: jaypur.
# Retrieving Results for Index 101: belushya guba.
# Retrieving Results for Index 101: belushya guba.
# Retrieving Results for Index 102: spartanburg.
# Retrieving Results for Index 103: luderitz.
# Retrieving Results for Index 104: atuona.
# Retrieving Results for Index 105: nikolskoye.
# Retrieving Results for Index 106: port elizabeth.
# Retrieving Results for Index 107: uray.
# Retrieving Results for Index 108: koran.
# Retrieving Results for Index 109: taolanaro.
# Retrieving Results for Index 109: taolanaro.
# Retrieving Results for Index 110: wasilla.
# Retrieving Results for Index 111: borlange.
# Retrieving Results for Index 111: borlange.
# Retrieving Results for Index 112: cabo san lucas.
# Retrieving Results for Index 113: zhangjiakou.
# Retrieving Results for Index 114: dobryanka.
# Retrieving Results for Index 115: mayskiy.
# Retrieving Results for Index 116: tigzirt.
# Retrieving Results for Index 117: alice springs.
# Retrieving Results for Index 118: tasiilaq.
# Retrieving Results for Index 119: katsuura.
# Retrieving Results for Index 120: athens.
# Retrieving Results for Index 121: port alfred.
# Retrieving Results for Index 122: lixourion.
# Retrieving Results for Index 123: lakes entrance.
# Retrieving Results for Index 124: bubaque.
# Retrieving Results for Index 125: hilo.
# Retrieving Results for Index 126: sioux lookout.
# Retrieving Results for Index 127: santarem.
# Retrieving Results for Index 128: saint-philippe.
# Retrieving Results for Index 129: laje.
# Retrieving Results for Index 130: saint-francois.
# Retrieving Results for Index 131: valle del guamuez.
# Retrieving Results for Index 132: vostok.
# Retrieving Results for Index 133: tabou.
# Retrieving Results for Index 134: conceicao do araguaia.
# Retrieving Results for Index 135: east london.
# Retrieving Results for Index 136: marawi.
# Retrieving Results for Index 137: yulara.
# Retrieving Results for Index 138: dorogobuzh.
# Retrieving Results for Index 139: tuktoyaktuk.
# Retrieving Results for Index 140: meiganga.
# Retrieving Results for Index 141: broken hill.
# Retrieving Results for Index 142: naze.
# Retrieving Results for Index 143: nantucket.
# Retrieving Results for Index 144: gizo.
# Retrieving Results for Index 145: tidore.
# Retrieving Results for Index 145: tidore.
# Retrieving Results for Index 146: butaritari.
# Retrieving Results for Index 147: skalistyy.
# Retrieving Results for Index 147: skalistyy.
# Retrieving Results for Index 148: isangel.
# Retrieving Results for Index 149: sao filipe.
# Retrieving Results for Index 150: margate.
# Retrieving Results for Index 151: upernavik.
# Retrieving Results for Index 152: kruisfontein.
# Retrieving Results for Index 153: sola.
# Retrieving Results for Index 154: chuy.
# Retrieving Results for Index 155: davlekanovo.
# Retrieving Results for Index 156: morris.
# Retrieving Results for Index 157: tanabe.
# Retrieving Results for Index 158: santiago.
# Retrieving Results for Index 159: narsaq.
# Retrieving Results for Index 160: oktyabrskoye.
# Retrieving Results for Index 161: nanortalik.
# Retrieving Results for Index 162: rimbey.
# Retrieving Results for Index 163: chokurdakh.
# Retrieving Results for Index 164: barcelos.
# Retrieving Results for Index 165: surt.
# Retrieving Results for Index 166: hasaki.
# Retrieving Results for Index 167: muisne.
# Retrieving Results for Index 168: sistranda.
# Retrieving Results for Index 169: sorvag.
# Retrieving Results for Index 169: sorvag.
# Retrieving Results for Index 170: charters towers.
# Retrieving Results for Index 171: barawe.
# Retrieving Results for Index 171: barawe.
# Retrieving Results for Index 172: praia.
# Retrieving Results for Index 173: estelle.
# Retrieving Results for Index 174: lavrentiya.
# Retrieving Results for Index 175: kapra.
# Retrieving Results for Index 176: bethel.
# Retrieving Results for Index 177: tupik.
# Retrieving Results for Index 178: edgewater.
# Retrieving Results for Index 179: verkhoyansk.
# Retrieving Results for Index 180: krasnyy chikoy.
# Retrieving Results for Index 181: bay roberts.
# Retrieving Results for Index 182: mayor pablo lagerenza.
# Retrieving Results for Index 183: koungou.
# Retrieving Results for Index 184: ust-ilimsk.
# Retrieving Results for Index 185: itoman.
# Retrieving Results for Index 186: pisco.
# Retrieving Results for Index 187: half moon bay.
# Retrieving Results for Index 188: cochrane.
# Retrieving Results for Index 189: dingle.
# Retrieving Results for Index 190: lake city.
# Retrieving Results for Index 191: mainpuri.
# Retrieving Results for Index 192: coquimbo.
# Retrieving Results for Index 193: carnarvon.
# Retrieving Results for Index 194: liancheng.
# Retrieving Results for Index 195: port hardy.
# Retrieving Results for Index 196: pangody.
# Retrieving Results for Index 197: arlit.
# Retrieving Results for Index 198: morehead.
# Retrieving Results for Index 199: hualmay.
# Retrieving Results for Index 200: tabiauea.
# Retrieving Results for Index 200: tabiauea.
# Retrieving Results for Index 201: banepa.
# Retrieving Results for Index 202: torbay.
# Retrieving Results for Index 203: lappeenranta.
# Retrieving Results for Index 204: ambulu.
# Retrieving Results for Index 205: requena.
# Retrieving Results for Index 206: amarante do maranhao.
# Retrieving Results for Index 207: kavaratti.
# Retrieving Results for Index 208: west wendover.
# Retrieving Results for Index 209: bathsheba.
# Retrieving Results for Index 210: mount gambier.
# Retrieving Results for Index 211: moussoro.
# Retrieving Results for Index 212: westport.
# Retrieving Results for Index 213: nizhneyansk.
# Retrieving Results for Index 213: nizhneyansk.
# Retrieving Results for Index 214: lompoc.
# Retrieving Results for Index 215: surovikino.
# Retrieving Results for Index 216: sao gabriel da cachoeira.
# Retrieving Results for Index 217: udachnyy.
# Retrieving Results for Index 218: kilinochchi.
# Retrieving Results for Index 219: katangli.
# Retrieving Results for Index 220: port lincoln.
# Retrieving Results for Index 221: roald.
# Retrieving Results for Index 222: longyearbyen.
# Retrieving Results for Index 223: auki.
# Retrieving Results for Index 224: kaeo.
# Retrieving Results for Index 225: gogrial.
# Retrieving Results for Index 226: rudiskes.
# Retrieving Results for Index 227: yadrin.
# Retrieving Results for Index 228: pacaembu.
# Retrieving Results for Index 229: goure.
# Retrieving Results for Index 230: muroto.
# Retrieving Results for Index 231: srednekolymsk.
# Retrieving Results for Index 232: kampene.
# Retrieving Results for Index 233: buritizeiro.
# Retrieving Results for Index 234: lahan.
# Retrieving Results for Index 235: vermillion.
# Retrieving Results for Index 236: visby.
# Retrieving Results for Index 237: avarua.
# Retrieving Results for Index 238: college.
# Retrieving Results for Index 239: pokhara.
# Retrieving Results for Index 240: balikpapan.
# Retrieving Results for Index 241: minbu.
# Retrieving Results for Index 242: freeport.
# Retrieving Results for Index 243: port macquarie.
# Retrieving Results for Index 244: maragogi.
# Retrieving Results for Index 245: rostovka.
# Retrieving Results for Index 246: araouane.
# Retrieving Results for Index 247: arraial do cabo.
# Retrieving Results for Index 248: lorengau.
# Retrieving Results for Index 249: sept-iles.
# Retrieving Results for Index 250: hua hin.
# Retrieving Results for Index 251: buldana.
# Retrieving Results for Index 252: kudat.
# Retrieving Results for Index 253: bellary.
# Retrieving Results for Index 254: castro.
# Retrieving Results for Index 255: marondera.
# Retrieving Results for Index 256: khonuu.
# Retrieving Results for Index 256: khonuu.
# Retrieving Results for Index 257: saint-augustin.
# Retrieving Results for Index 258: deutschlandsberg.
# Retrieving Results for Index 259: ushtobe.
# Retrieving Results for Index 260: olden.
# Retrieving Results for Index 261: gimli.
# Retrieving Results for Index 262: riyadh.
# Retrieving Results for Index 263: souillac.
# Retrieving Results for Index 264: kahului.
# Retrieving Results for Index 265: komsomolskiy.
# Retrieving Results for Index 266: port blair.
# Retrieving Results for Index 267: kaitangata.
# Retrieving Results for Index 268: thompson.
# Retrieving Results for Index 269: mujiayingzi.
# Retrieving Results for Index 270: san quintin.
# Retrieving Results for Index 271: fairbanks.
# Retrieving Results for Index 272: lebu.
# Retrieving Results for Index 273: englewood.
# Retrieving Results for Index 274: tabas.
# Retrieving Results for Index 275: mangai.
# Retrieving Results for Index 276: aljezur.
# Retrieving Results for Index 277: nanakuli.
# Retrieving Results for Index 278: fort nelson.
# Retrieving Results for Index 279: rundu.
# Retrieving Results for Index 280: lieksa.
# Retrieving Results for Index 281: jangaon.
# Retrieving Results for Index 282: saint-leu.
# Retrieving Results for Index 283: toumodi.
# Retrieving Results for Index 284: chimore.
# Retrieving Results for Index 285: avera.
# Retrieving Results for Index 286: padang.
# Retrieving Results for Index 287: warqla.
# Retrieving Results for Index 287: warqla.
# Retrieving Results for Index 288: salalah.
# Retrieving Results for Index 289: dikson.
# Retrieving Results for Index 290: athabasca.
# Retrieving Results for Index 291: gamba.
# Retrieving Results for Index 292: howard springs.
# Retrieving Results for Index 293: xining.
# Retrieving Results for Index 294: tolaga bay.
# Retrieving Results for Index 295: camabatela.
# Retrieving Results for Index 296: peleduy.
# Retrieving Results for Index 297: namatanai.
# Retrieving Results for Index 298: aksarka.
# Retrieving Results for Index 299: kenai.
# Retrieving Results for Index 300: ksenyevka.
# Retrieving Results for Index 300: ksenyevka.
# Retrieving Results for Index 301: raudeberg.
# Retrieving Results for Index 302: sentyabrskiy.
# Retrieving Results for Index 302: sentyabrskiy.
# Retrieving Results for Index 303: ziyamet.
# Retrieving Results for Index 303: ziyamet.
# Retrieving Results for Index 304: bilibino.
# Retrieving Results for Index 305: banjarmasin.
# Retrieving Results for Index 306: liverpool.
# Retrieving Results for Index 307: namie.
# Retrieving Results for Index 308: adelaide.
# Retrieving Results for Index 309: astoria.
# Retrieving Results for Index 310: ferrol.
# Retrieving Results for Index 311: sawakin.
# Retrieving Results for Index 312: mys shmidta.
# Retrieving Results for Index 312: mys shmidta.
# Retrieving Results for Index 313: escanaba.
# Retrieving Results for Index 314: jinxiang.
# Retrieving Results for Index 315: iqaluit.
# Retrieving Results for Index 316: nago.
# Retrieving Results for Index 317: tautira.
# Retrieving Results for Index 318: colares.
# Retrieving Results for Index 319: nazareno.
# Retrieving Results for Index 320: ambilobe.
# Retrieving Results for Index 321: provideniya.
# Retrieving Results for Index 322: hobyo.
# Retrieving Results for Index 323: leningradskiy.
# Retrieving Results for Index 324: trinidad.
# Retrieving Results for Index 325: tura.
# Retrieving Results for Index 326: roebourne.
# Retrieving Results for Index 327: karacabey.
# Retrieving Results for Index 328: vila franca do campo.
# Retrieving Results for Index 329: nizhneivkino.
# Retrieving Results for Index 330: kernersville.
# Retrieving Results for Index 331: kysyl-syr.
# Retrieving Results for Index 332: haines junction.
# Retrieving Results for Index 333: spring valley.
# Retrieving Results for Index 334: sitka.
# Retrieving Results for Index 335: taoudenni.
# Retrieving Results for Index 336: axim.
# Retrieving Results for Index 337: maceio.
# Retrieving Results for Index 338: ahipara.
# Retrieving Results for Index 339: oxford.
# Retrieving Results for Index 340: ust-kuyga.
# Retrieving Results for Index 341: addanki.
# Retrieving Results for Index 342: afua.
# Retrieving Results for Index 343: nurlat.
# Retrieving Results for Index 344: barentsburg.
# Retrieving Results for Index 344: barentsburg.
# Retrieving Results for Index 345: kidal.
# Retrieving Results for Index 346: talnakh.
# Retrieving Results for Index 347: gat.
# Retrieving Results for Index 348: san patricio.
# Retrieving Results for Index 349: necochea.
# Retrieving Results for Index 350: macaubas.
# Retrieving Results for Index 351: bucsa.
# Retrieving Results for Index 352: khatanga.
# Retrieving Results for Index 353: rajbiraj.
# Retrieving Results for Index 354: inhambane.
# Retrieving Results for Index 355: ust-uda.
# Retrieving Results for Index 356: pueblo nuevo.
# Retrieving Results for Index 357: kailua.
# Retrieving Results for Index 358: fengrun.
# Retrieving Results for Index 359: baruun-urt.
# Retrieving Results for Index 360: clyde river.
# Retrieving Results for Index 361: ust-kamchatsk.
# Retrieving Results for Index 361: ust-kamchatsk.
# Retrieving Results for Index 362: djambala.
# Retrieving Results for Index 363: caravelas.
# Retrieving Results for Index 364: baykit.
# Retrieving Results for Index 365: kavieng.
# Retrieving Results for Index 366: esmeraldas.
# Retrieving Results for Index 367: mankono.
# Retrieving Results for Index 368: peterhead.
# Retrieving Results for Index 369: baiyin.
# Retrieving Results for Index 370: doraville.
# Retrieving Results for Index 371: mbaiki.
# Retrieving Results for Index 372: gerash.
# Retrieving Results for Index 373: chortkiv.
# Retrieving Results for Index 374: paramonga.
# Retrieving Results for Index 375: porto novo.
# Retrieving Results for Index 376: tombouctou.
# Retrieving Results for Index 377: cherskiy.
# Retrieving Results for Index 378: indianola.
# Retrieving Results for Index 379: eagle pass.
# Retrieving Results for Index 380: vestmanna.
# Retrieving Results for Index 381: kamenskoye.
# Retrieving Results for Index 381: kamenskoye.
# Retrieving Results for Index 382: codrington.
# Retrieving Results for Index 383: lasa.
# Retrieving Results for Index 384: ilulissat.
# Retrieving Results for Index 385: pacific grove.
# Retrieving Results for Index 386: kamaishi.
# Retrieving Results for Index 387: nguiu.
# Retrieving Results for Index 387: nguiu.
# Retrieving Results for Index 388: hambantota.
# Retrieving Results for Index 389: port augusta.
# Retrieving Results for Index 390: halifax.
# Retrieving Results for Index 391: neuquen.
# Retrieving Results for Index 392: mabaruma.
# Retrieving Results for Index 393: paamiut.
# Retrieving Results for Index 394: turayf.
# Retrieving Results for Index 395: salinas.
# Retrieving Results for Index 396: mirnyy.
# Retrieving Results for Index 397: sarakhs.
# Retrieving Results for Index 398: staryy saltiv.
# Retrieving Results for Index 399: nadadores.
# Retrieving Results for Index 400: svetlogorsk.
# Retrieving Results for Index 401: nome.
# Retrieving Results for Index 402: vinh.
# Retrieving Results for Index 403: ranong.
# Retrieving Results for Index 404: colgong.
# Retrieving Results for Index 405: at-bashi.
# Retrieving Results for Index 406: deputatskiy.
# Retrieving Results for Index 407: cayenne.
# Retrieving Results for Index 408: denia.
# Retrieving Results for Index 409: boddam.
# Retrieving Results for Index 410: mustang.
# Retrieving Results for Index 411: karlskrona.
# Retrieving Results for Index 412: klaksvik.
# Retrieving Results for Index 413: fort saint john.
# Retrieving Results for Index 413: fort saint john.
# Retrieving Results for Index 414: klyuchi.
# Retrieving Results for Index 415: geraldton.
# Retrieving Results for Index 416: srivardhan.
# Retrieving Results for Index 417: quatre cocos.
# Retrieving Results for Index 418: norman wells.
# Retrieving Results for Index 419: clinton.
# Retrieving Results for Index 420: suzu.
# Retrieving Results for Index 420: suzu.
# Retrieving Results for Index 421: esperance.
# Retrieving Results for Index 422: waingapu.
# Retrieving Results for Index 423: yeppoon.
# Retrieving Results for Index 424: prince rupert.
# Retrieving Results for Index 425: aquiraz.
# Retrieving Results for Index 426: lata.
# Retrieving Results for Index 427: tuatapere.
# Retrieving Results for Index 428: santa cruz cabralia.
# Retrieving Results for Index 429: orumiyeh.
# Retrieving Results for Index 430: novyy urengoy.
# Retrieving Results for Index 431: la asuncion.
# Retrieving Results for Index 432: kamenka.
# Retrieving Results for Index 433: vao.
# Retrieving Results for Index 434: trairi.
# Retrieving Results for Index 435: zhirnov.
# Retrieving Results for Index 436: vila velha.
# Retrieving Results for Index 437: taft.
# Retrieving Results for Index 438: saint-georges.
# Retrieving Results for Index 439: pitimbu.
# Retrieving Results for Index 440: kemijarvi.
# Retrieving Results for Index 441: nelson bay.
# Retrieving Results for Index 442: taseyevo.
# Retrieving Results for Index 443: walvis bay.
# Retrieving Results for Index 444: sorland.
# Retrieving Results for Index 445: faanui.
# Retrieving Results for Index 446: adre.
# Retrieving Results for Index 447: namibe.
# Retrieving Results for Index 448: samarai.
# Retrieving Results for Index 449: najran.
# Retrieving Results for Index 450: saint-joseph.
# Retrieving Results for Index 451: ambovombe.
# Retrieving Results for Index 452: talara.
# Retrieving Results for Index 453: olinda.
# Retrieving Results for Index 454: bairiki.
# Retrieving Results for Index 455: temaraia.
# Retrieving Results for Index 455: temaraia.
# Retrieving Results for Index 456: muros.
# Retrieving Results for Index 457: pangkalanbuun.
# Retrieving Results for Index 458: saldanha.
# Retrieving Results for Index 459: kasama.
# Retrieving Results for Index 460: dalby.
# Retrieving Results for Index 461: kirakira.
# Retrieving Results for Index 462: nara.
# Retrieving Results for Index 463: copiapo.
# Retrieving Results for Index 464: ilhabela.
# Retrieving Results for Index 465: mnogovershinnyy.
# Retrieving Results for Index 466: soyo.
# Retrieving Results for Index 467: panalingaan.
# Retrieving Results for Index 468: los alamos.
# Retrieving Results for Index 469: taguatinga.
# Retrieving Results for Index 470: cascais.
# Retrieving Results for Index 471: ayan.
# Retrieving Results for Index 472: prince george.
# Retrieving Results for Index 473: puri.
# Retrieving Results for Index 474: wulanhaote.
# Retrieving Results for Index 474: wulanhaote.
# Retrieving Results for Index 475: hokitika.
# Retrieving Results for Index 476: kerema.
# Retrieving Results for Index 477: leh.
# Retrieving Results for Index 478: mundwa.
# Retrieving Results for Index 479: mitu.
# Retrieving Results for Index 480: san martin.
# Retrieving Results for Index 481: coffs harbour.
# Retrieving Results for Index 482: tilichiki.
# Retrieving Results for Index 483: gold coast.
# Retrieving Results for Index 484: kendari.
# Retrieving Results for Index 485: dois irmaos.
# Retrieving Results for Index 486: verkhnevilyuysk.
# Retrieving Results for Index 487: ostrovnoy.
# Retrieving Results for Index 488: sapouy.
# Retrieving Results for Index 489: fethiye.
# Retrieving Results for Index 490: fayetteville.
# Retrieving Results for Index 491: meyungs.
# Retrieving Results for Index 491: meyungs.
# Retrieving Results for Index 492: saint anthony.
# Retrieving Results for Index 493: duluth.
# Retrieving Results for Index 494: launceston.
# Retrieving Results for Index 495: karakendzha.
# Retrieving Results for Index 495: karakendzha.
# Retrieving Results for Index 496: northfield.
# Retrieving Results for Index 497: viedma.
# Retrieving Results for Index 498: poya.
# Retrieving Results for Index 499: ikalamavony.
# Retrieving Results for Index 500: mardin.
# Retrieving Results for Index 501: hofn.
# Retrieving Results for Index 502: bambanglipuro.
# Retrieving Results for Index 503: shenzhen.
# Retrieving Results for Index 504: dubbo.
# Retrieving Results for Index 505: metro.
# Retrieving Results for Index 506: rawatbhata.
# Retrieving Results for Index 507: crab hill.
# Retrieving Results for Index 507: crab hill.
# Retrieving Results for Index 508: dujuma.
# Retrieving Results for Index 508: dujuma.
# Retrieving Results for Index 509: oranjemund.
# Retrieving Results for Index 510: black river.
# Retrieving Results for Index 511: hirara.
# Retrieving Results for Index 512: cortland.
# Retrieving Results for Index 513: pinawa.
# Retrieving Results for Index 514: marv dasht.
# Retrieving Results for Index 514: marv dasht.
# Retrieving Results for Index 515: kupang.
# Retrieving Results for Index 516: smoky lake.
# Retrieving Results for Index 517: grindavik.
# Retrieving Results for Index 518: rawson.
# Retrieving Results for Index 519: novogurovskiy.
# Retrieving Results for Index 520: henties bay.
# Retrieving Results for Index 521: palmer.
# Retrieving Results for Index 522: camocim.
# Retrieving Results for Index 523: chanute.
# Retrieving Results for Index 524: ancud.
# Retrieving Results for Index 525: dracsenei.
# Retrieving Results for Index 525: dracsenei.
# Retrieving Results for Index 526: ketchikan.
# Retrieving Results for Index 527: san cristobal.
# Retrieving Results for Index 528: hoi an.
# Retrieving Results for Index 529: jardim.
# Retrieving Results for Index 530: sol-iletsk.
# Retrieving Results for Index 531: padilla.
# Retrieving Results for Index 532: ardino.
# Retrieving Results for Index 533: san jose.
# Retrieving Results for Index 534: tekeli.
# Retrieving Results for Index 535: dawei.
# Retrieving Results for Index 536: santa isabel do rio negro.
# Retrieving Results for Index 537: neiafu.
# Retrieving Results for Index 538: amahai.
# Retrieving Results for Index 539: yugo-kamskiy.
# Retrieving Results for Index 540: aleksandrov gay.
# Retrieving Results for Index 541: barra do garcas.
# Retrieving Results for Index 542: izhma.
# Retrieving Results for Index 543: shache.
# Retrieving Results for Index 544: havre-saint-pierre.
# Retrieving Results for Index 545: bacuit.
# Retrieving Results for Index 545: bacuit.
# Retrieving Results for Index 546: san vicente.
# Retrieving Results for Index 547: alofi.
# Retrieving Results for Index 548: hearst.
# Retrieving Results for Index 549: constitucion.
# Retrieving Results for Index 550: kiama.
# Retrieving Results for Index 551: natal.
# Retrieving Results for Index 552: lensk.
# Retrieving Results for Index 553: calama.
# Retrieving Results for Index 554: wodonga.
# Retrieving Results for Index 555: golspie.
# Retrieving Results for Index 556: asau.
# Retrieving Results for Index 557: vuktyl.
# Retrieving Results for Index 558: petropavlovsk-kamchatskiy.
# Retrieving Results for Index 559: ust-nera.
# Retrieving Results for Index 560: bid.
# Retrieving Results for Index 560: bid.
# Retrieving Results for Index 561: ladispoli.
# Retrieving Results for Index 562: gidam.
# Retrieving Results for Index 563: grand gaube.
# Retrieving Results for Index 564: harper.
# Retrieving Results for Index 565: imuris.
# Retrieving Results for Index 566: haicheng.
# Retrieving Results for Index 567: lenki.
# Retrieving Results for Index 567: lenki.
# Retrieving Results for Index 568: yialos.
# Retrieving Results for Index 568: yialos.
# Retrieving Results for Index 569: bara.
# Retrieving Results for Index 570: alyangula.
# Retrieving Results for Index 571: huarmey.
# Retrieving Results for Index 572: eskasem.
# Retrieving Results for Index 572: eskasem.
# Retrieving Results for Index 573: yanan.
# Retrieving Results for Index 573: yanan.
# Retrieving Results for Index 574: cody.
# Retrieving Results for Index 575: kazalinsk.
# Retrieving Results for Index 575: kazalinsk.
# Retrieving Results for Index 576: mazagao.
# Retrieving Results for Index 577: faya.
# Retrieving Results for Index 578: gravdal.
# Retrieving Results for Index 579: mackenzie.
# Retrieving Results for Index 580: anuchino.
# Retrieving Results for Index 581: bereda.
# Retrieving Results for Index 582: carballo.
# Retrieving Results for Index 583: storforshei.
# Retrieving Results for Index 584: yaan.
# Retrieving Results for Index 585: mahibadhoo.
# Retrieving Results for Index 586: acapulco.
# Retrieving Results for Index 587: chico.
# Retrieving Results for Index 588: lahaina.
# Retrieving Results for Index 589: wewak.
# Retrieving Results for Index 590: goderich.
# Retrieving Results for Index 591: alekseyevsk.
# Retrieving Results for Index 592: mehamn.
# Retrieving Results for Index 593: mocuba.
# Retrieving Results for Index 594: abu kamal.
# Retrieving Results for Index 595: waipawa.
# Retrieving Results for Index 596: urengoy.
# Retrieving Results for Index 597: bargal.
# Retrieving Results for Index 597: bargal.
# Retrieving Results for Index 598: belyy yar.
# Retrieving Results for Index 599: pakokku.
# Retrieving Results for Index 600: benguela.
# Retrieving Results for Index 601: lumberton.
# Retrieving Results for Index 602: karratha.
# Retrieving Results for Index 603: meulaboh.
# Retrieving Results for Index 604: puerto madryn.
# Retrieving Results for Index 605: kembolcha.
# Retrieving Results for Index 606: veseloyarsk.
# Retrieving Results for Index 607: orissaare.
# Retrieving Results for Index 608: adrar.
# Retrieving Results for Index 609: hameenlinna.
# Retrieving Results for Index 610: quelimane.
# Retrieving Results for Index 611: scarborough.
# Retrieving Results for Index 612: boguchany.
# Retrieving Results for Index 613: liwale.
# Retrieving Results for Index 614: santo nino.
# Retrieving Results for Index 615: minna.
# Retrieving Results for Index 616: turochak.
# Retrieving Results for Index 617: acarau.
# Retrieving Results for Index 618: calabazar de sagua.
# Retrieving Results for Index 619: maloshuyka.
# Retrieving Results for Index 619: maloshuyka.
# Retrieving Results for Index 620: bayan.
# Retrieving Results for Index 621: itacoatiara.
# Retrieving Results for Index 622: laguna.
# Retrieving Results for Index 623: nuuk.
# Retrieving Results for Index 624: del rio.
# Retrieving Results for Index 625: beloha.

# %%
cities_df
# Out:
#              Cities Forecast  Cloudiness (%) Country                Date  \
# 0              teya    Clear             1.0      RU 2020-04-11 13:13:17
# 1             korla   Clouds            17.0      CN 2020-04-11 13:14:43
# 2           aklavik   Clouds            20.0      CA 2020-04-11 13:10:37
# 3      attawapiskat      NaN             NaN     NaN                 NaT
# 4    ribeira grande   Clouds            20.0      PT 2020-04-11 13:14:43
# ..              ...      ...             ...     ...                 ...
# 621     itacoatiara     Rain           100.0      BR 2020-04-11 13:15:58
# 622          laguna   Clouds            90.0      US 2020-04-11 13:13:00
# 623            nuuk   Clouds            99.0      GL 2020-04-11 13:15:59
# 624         del rio   Clouds            90.0      US 2020-04-11 13:12:23
# 625          beloha     Rain            88.0      MG 2020-04-11 13:15:59
#
#      Humidity    Lat     Lng  Max Temperature (F)  Wind Speed (mph)
# 0        94.0  60.38   92.63                24.39              4.03
# 1        21.0  41.76   86.15                58.80              3.67
# 2        84.0  68.22 -135.01                 5.00              4.70
# 3         NaN    NaN     NaN                  NaN               NaN
# 4        77.0  38.52  -28.70                64.40              4.70
# ..        ...    ...     ...                  ...               ...
# 621      95.0  -3.14  -58.44                76.30              3.76
# 622      82.0  38.42 -121.42                59.00              4.70
# 623      69.0  64.18  -51.72                39.20              4.70
# 624      78.0  29.36 -100.90                73.40             14.99
# 625      81.0 -25.17   45.05                73.08             16.22
#
# [626 rows x 10 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.columns
cities_df.to_csv (r'city_weather_dataframe.csv', index = False, header=True)

# %%
cities_df
# Out:
#              Cities Forecast  Cloudiness (%) Country                Date  \
# 0              teya    Clear             1.0      RU 2020-04-11 13:13:17
# 1             korla   Clouds            17.0      CN 2020-04-11 13:14:43
# 2           aklavik   Clouds            20.0      CA 2020-04-11 13:10:37
# 3      attawapiskat      NaN             NaN     NaN                 NaT
# 4    ribeira grande   Clouds            20.0      PT 2020-04-11 13:14:43
# ..              ...      ...             ...     ...                 ...
# 621     itacoatiara     Rain           100.0      BR 2020-04-11 13:15:58
# 622          laguna   Clouds            90.0      US 2020-04-11 13:13:00
# 623            nuuk   Clouds            99.0      GL 2020-04-11 13:15:59
# 624         del rio   Clouds            90.0      US 2020-04-11 13:12:23
# 625          beloha     Rain            88.0      MG 2020-04-11 13:15:59
#
#      Humidity    Lat     Lng  Max Temperature (F)  Wind Speed (mph)
# 0        94.0  60.38   92.63                24.39              4.03
# 1        21.0  41.76   86.15                58.80              3.67
# 2        84.0  68.22 -135.01                 5.00              4.70
# 3         NaN    NaN     NaN                  NaN               NaN
# 4        77.0  38.52  -28.70                64.40              4.70
# ..        ...    ...     ...                  ...               ...
# 621      95.0  -3.14  -58.44                76.30              3.76
# 622      82.0  38.42 -121.42                59.00              4.70
# 623      69.0  64.18  -51.72                39.20              4.70
# 624      78.0  29.36 -100.90                73.40             14.99
# 625      81.0 -25.17   45.05                73.08             16.22
#
# [626 rows x 10 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# print(cities_df["Max Temperature (F)"])
# print(cities_df["Lat"])
plt.scatter(cities_df["Lat"], cities_df["Max Temperature (F)"])
plt.title("Latitude of Cities vs Max Temperature in Farenheit")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Max Temperature (F)"].min() - 10, cities_df["Max Temperature (F)"].max() + 10)
plt.grid(True, which = "major")

# %%
# What we are seeing in this plot is a tendency of Temperature get warmer the closer it is to the equator (latitude = 0).

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# print(cities_df["Humidity"])
# print(cities_df["Lat"])

plt.scatter(cities_df["Lat"], cities_df["Humidity"])
plt.title("Latitude of Cities vs Percent Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Humidity"].min() - 10, cities_df["Humidity"].max() + 10)
plt.grid(True, which = "major")

# %%
# If the latitude is closer to 0, then the humidity seems to be higher. The further away from the equator it is, the less reliable or more random the humidity % seems to be.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# print(cities_df["Lat"])
# print(cities_df["Cloudiness (%)"])

plt.scatter(cities_df["Lat"], cities_df["Cloudiness (%)"])
plt.title("Latitude of Cities vs Percent Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Cloudiness (%)"].min() - 10, cities_df["Cloudiness (%)"].max() + 10)
plt.grid(True, which = "major")

# %%
# From this plot it seems like there are inconclusive results. The scatter plot seems to be random.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(cities_df["Lat"], cities_df["Wind Speed (mph)"])
plt.title("Latitude of Cities vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylim(cities_df["Wind Speed (mph)"].min() - 10, cities_df["Wind Speed (mph)"].max() + 10)
plt.grid(True, which = "major")

# %%
# In this plot, it seems like wind speeds are low for each of the randomly generated cities. There are a few outliers but there isn't much of a conclusion from this plot.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
# Take information from cities_df and transfer to another data frame

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df= cities_df.loc[cities_df['Lat'] >= 0, :]
southern_df = cities_df.loc[cities_df['Lat'] < 0, :]
# northern_df
# southern_df

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Max Temperature (F)"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Northern Hemisphere - Max Temperature vs Latitude")

slope_n1, intercept_n1, rvalue_n1, pvalue_n1, stderr_n1 = linregress(northern_df["Lat"], northern_df["Max Temperature (F)"])
lin_req_annotate = str(f"y = {round(slope_n1,ndigits=2)}x + {round(intercept_n1,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n1 + slope_n1*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate, (0,-10))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n1**2,ndigits = 3)}')
# Out:
# R-squared is 0.763

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Max Temperature (F)"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Southern Hemisphere - Max Temperature vs Latitude")

slope_s1, intercept_s1, rvalue_s1, pvalue_s1, stderr_s1 = linregress(southern_df["Lat"], southern_df["Max Temperature (F)"])
lin_req_annotate2 = str(f"y = {round(slope_s1, ndigits=2)}x + {round(intercept_s1,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s1 + slope_s1*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate2, (-25,50))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_s1**2,ndigits = 3)}')
# Out:
# R-squared is 0.57

# %%
# The two plots are essentially concluding the same thing. The only reason that there is a positive slope vs a negative slope is because of the nature of the latitude.
# Essentially the closer the latitude gets to 0, the higher the temperature will be.

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("Northern Hemisphere - Humidity vs Latitude")

slope_n2, intercept_n2, rvalue_n2, pvalue_n2, stderr_n2 = linregress(northern_df["Lat"], northern_df["Humidity"])
lin_req_annotate3 = str(f"y = {round(slope_n2,ndigits=2)}x + {round(intercept_n2,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n2 + slope_n2*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate3, (55,15))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n2**2,ndigits = 3)}')
# Out:
# R-squared is 0.089

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity vs Latitude")

slope_s2, intercept_s2, rvalue_s2, pvalue_s2, stderr_s2 = linregress(southern_df["Lat"], southern_df["Humidity"])
lin_req_annotate4 = str(f"y = {round(slope_s2, ndigits=2)}x + {round(intercept_s2,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s2 + slope_s2*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate4, (-55,50))
plt.legend()
plt.show()

# %%
# There are fewer points in the southern hemisphere compared to the northern hemisphere; one would expect that the humidity would be higher as it gets closer to the equator.
# There may be fewer points in the southern hemisphere because there is more land mass in the northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Cloudiness (%)"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Northern Hemisphere - Cloudiness % vs Latitude")

slope_n3, intercept_n3, rvalue_n3, pvalue_n3, stderr_n3 = linregress(northern_df["Lat"], northern_df["Cloudiness (%)"])
lin_req_annotate4 = str(f"y = {round(slope_n3,ndigits=2)}x + {round(intercept_n3,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n3 + slope_n3*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate4, (60,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n3**2,ndigits = 3)}')
# Out:
# R-squared is 0.044

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Cloudiness (%)"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("Southern Hemisphere - Cloudiness % vs Latitude")

slope_s3, intercept_s3, rvalue_s3, pvalue_s3, stderr_s3 = linregress(southern_df["Lat"], southern_df["Cloudiness (%)"])
lin_req_annotate5 = str(f"y = {round(slope_s3,ndigits=2)}x + {round(intercept_s3,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s3 + slope_s3*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate5, (-52,25))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_s3**2,ndigits = 3)}')
# Out:
# R-squared is 0.028

# %%
# The slope on both northern and southern hemisphere are similar, there seems to be a positive slope but that can also be attributed to there being more points in the northern hemisphere. 
# In reality the cloudiness of a city doesn't have much of a correlation compared to the latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(northern_df["Lat"], northern_df["Wind Speed (mph)"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed vs Latitude")

slope_n4, intercept_n4, rvalue_n4, pvalue_n4, stderr_n4 = linregress(northern_df["Lat"], northern_df["Wind Speed (mph)"])
lin_req_annotate6 = str(f"y = {round(slope_n4,ndigits=2)}x + {round(intercept_n4,ndigits=2)}")
plt.plot(northern_df["Lat"], intercept_n4 + slope_n4*northern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate6, (60,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_n4**2,ndigits = 3)}')
# Out:
# R-squared is 0.014

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(southern_df["Lat"], southern_df["Wind Speed (mph)"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed vs Latitude")

slope_s4, intercept_s4, rvalue_s4, pvalue_s4, stderr_s4 = linregress(southern_df["Lat"], southern_df["Wind Speed (mph)"])
lin_req_annotate7 = str(f"y = {round(slope_s4,ndigits=2)}x + {round(intercept_s4,ndigits=2)}")
plt.plot(southern_df["Lat"], intercept_s4 + slope_s4*southern_df["Lat"], 'r', label='fitted line')
plt.annotate(lin_req_annotate7, (-50,8))
plt.legend()
plt.show()
print(f'R-squared is {round(rvalue_s4**2,ndigits = 3)}')
# Out:
# R-squared is 0.144

# %%
# In the southern hemisphere there is a tendency for wind speeds to be lower the closer it gets to the equation.
# That statement doesn't hold true for the northern hemisphere. There doesn't seem to be a trend for wind speed in the northern hemisphere.
